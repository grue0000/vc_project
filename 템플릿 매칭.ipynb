# %%
# 사진에서 골프공, 퍼터 인식 코드

import cv2

src = cv2.imread("D_899_1/temp-04302021112709-792.bmp", cv2.IMREAD_GRAYSCALE)
templit = cv2.imread("ball.jpg", cv2.IMREAD_GRAYSCALE)
templit1 = cv2.imread("putter.jpg", cv2.IMREAD_GRAYSCALE)
dst = cv2.imread("D_899_1/temp-04302021112709-792.bmp")

result = cv2.matchTemplate(src, templit, cv2.TM_SQDIFF_NORMED)

minVal, maxVal, minLoc, maxLoc = cv2.minMaxLoc(result)
x, y = minLoc
h, w = templit.shape

result1 = cv2.matchTemplate(src, templit1, cv2.TM_SQDIFF_NORMED)

minVal1, maxVal1, minLoc1, maxLoc1 = cv2.minMaxLoc(result1)
x1, y1 = minLoc1
h1, w1 = templit1.shape

dst = cv2.rectangle(dst, (x, y), (x +  w, y + h) , (0, 0, 255), 1)
dst = cv2.rectangle(dst, (x1, y1), (x1 +  w1, y1 + h1) , (0, 0, 255), 1)

cv2.imshow("dst", dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
result
# Out:
# array([[0.16817339, 0.16993783, 0.17171186, ..., 0.13063504, 0.13074923,
#         0.13098058],
#        [0.17309102, 0.17470044, 0.176642  , ..., 0.13078442, 0.13105941,
#         0.13127832],
#        [0.17817791, 0.17960382, 0.18137005, ..., 0.13076316, 0.13093506,
#         0.13121583],
#        ...,
#        [0.12106348, 0.12115503, 0.12105642, ..., 0.13560207, 0.1355278 ,
#         0.13541996],
#        [0.11984976, 0.11981551, 0.11978905, ..., 0.13578358, 0.13588636,
#         0.13578764],
#        [0.11928404, 0.11909289, 0.11918363, ..., 0.13629726, 0.1362542 ,
#         0.13611695]], dtype=float32)

# %%
# 동영상에서 골프공 인식

# 시간 : t = 1/fps   x속도 : vx = (x-lx)/t    , y속도 : vy = (y-ly)/t

import cv2
import numpy as np

cap = cv2.VideoCapture('vid.mp4')

templit = cv2.imread("ball.jpg", cv2.IMREAD_GRAYSCALE)

width = int(cap.get(3)) # 가로 길이 가져오기 
height = int(cap.get(4)) # 세로 길이 가져오기
fps = 1

t = 1/fps

fcc = cv2.VideoWriter_fourcc('D', 'I', 'V', 'X')
out = cv2.VideoWriter('output.avi', fcc, fps, (width, height))

lx = 0
ly = 0

while (cap.isOpened()) :
    ret, frame = cap.read()
    if ret :
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        result = cv2.matchTemplate(gray, templit, cv2.TM_SQDIFF_NORMED)

        minVal, maxVal, minLoc, maxLoc = cv2.minMaxLoc(result)
        x, y = minLoc
        h, w = templit.shape
        
        gray = cv2.rectangle(frame, (x, y), (x +  w, y + h) , (0, 0, 255), 1)
        out.write(frame)
        cv2.imshow('frame', frame)
        
        vx = (x-lx)/t
        vy = (y-ly)/t
        
        print('x속도 : ',vx,'y속도 : ',vy)
        
        lx, ly = x, y
        
        if cv2.waitKey(1) & 0xFF == ord('q') : break
    else :
        print("Fail to read frame!")
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# x속도 :  195.0 y속도 :  29.0
# x속도 :  4.0 y속도 :  3.0
# x속도 :  58.0 y속도 :  473.0
# x속도 :  -85.0 y속도 :  -503.0
# x속도 :  1.0 y속도 :  22.0
# x속도 :  3.0 y속도 :  20.0
# x속도 :  2.0 y속도 :  19.0
# x속도 :  2.0 y속도 :  19.0
# x속도 :  2.0 y속도 :  21.0
# x속도 :  3.0 y속도 :  20.0
# x속도 :  4.0 y속도 :  20.0
# x속도 :  4.0 y속도 :  19.0
# x속도 :  3.0 y속도 :  19.0
# x속도 :  0.0 y속도 :  19.0
# x속도 :  3.0 y속도 :  20.0
# x속도 :  3.0 y속도 :  18.0
# x속도 :  3.0 y속도 :  17.0
# x속도 :  2.0 y속도 :  18.0
# x속도 :  3.0 y속도 :  18.0
# x속도 :  3.0 y속도 :  18.0
# x속도 :  4.0 y속도 :  17.0
# x속도 :  4.0 y속도 :  18.0
# x속도 :  2.0 y속도 :  17.0
# x속도 :  3.0 y속도 :  19.0
# x속도 :  3.0 y속도 :  18.0
# x속도 :  3.0 y속도 :  17.0
# x속도 :  2.0 y속도 :  17.0
# x속도 :  3.0 y속도 :  16.0
# x속도 :  1.0 y속도 :  18.0
# x속도 :  3.0 y속도 :  16.0
# x속도 :  1.0 y속도 :  15.0
# x속도 :  3.0 y속도 :  16.0
# x속도 :  1.0 y속도 :  15.0
# x속도 :  3.0 y속도 :  14.0
# x속도 :  2.0 y속도 :  15.0
# x속도 :  1.0 y속도 :  15.0
# x속도 :  1.0 y속도 :  15.0
# x속도 :  3.0 y속도 :  14.0
# x속도 :  2.0 y속도 :  14.0
# x속도 :  1.0 y속도 :  14.0
# x속도 :  4.0 y속도 :  14.0
# x속도 :  3.0 y속도 :  13.0
# x속도 :  -55.0 y속도 :  -60.0
# x속도 :  0.0 y속도 :  10.0
# x속도 :  -1.0 y속도 :  14.0
# x속도 :  -2.0 y속도 :  24.0
# x속도 :  3.0 y속도 :  7.0
# x속도 :  -29.0 y속도 :  -651.0
# x속도 :  1.0 y속도 :  0.0
# x속도 :  2.0 y속도 :  0.0
# x속도 :  0.0 y속도 :  0.0
# Fail to read frame!
